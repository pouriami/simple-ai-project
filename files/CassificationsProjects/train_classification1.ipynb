# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as pt 
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
df = pd.read_csv("../data/data.csv")

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
x = df.drop('price_range', axis=1)
y = df['price_range']

# %%
fig = pt.scatter(df,x='battery_power',y=y,color='price_range')
fig.show()

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.8,random_state=42)

# %%
knn = KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
random_data = [
    np.random.randint(1000, 5000),  
    np.random.randint(0, 2),        
    np.random.uniform(1.0, 3.0),    
    np.random.randint(0, 2),        
    np.random.randint(0, 20),       
    np.random.randint(0, 2),        
    np.random.randint(2, 128),      
    np.random.uniform(0.5, 1.5),    
    np.random.randint(100, 250),    
    np.random.randint(2, 8),        
    np.random.randint(0, 10),       
    np.random.randint(600, 3000),   
    np.random.randint(600, 3000),   
    np.random.randint(1, 16),       
    np.random.randint(1000, 3000),  
    np.random.randint(1000, 3000),  
    np.random.randint(10, 30),      
    np.random.randint(0, 2),        
    np.random.randint(0, 2),        
    np.random.randint(0, 2),        
]

# %%
x_new = np.array([random_data])
prediction = knn.predict(x_new)
print('prediction: {}'.format(prediction))
# Out:
# prediction: [1]
