# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_absolute_error
import numpy as np
from sklearn import preprocessing

# %%
def prepare_data(df, forecast_col, forecast_out, test_size):
    label = df[forecast_col].shift(-forecast_out)
    x = np.array(df[[forecast_col]])
    x = preprocessing.scale(x)
    x_lately = x[-forecast_out:]
    x = x[:-forecast_out]  
    label.dropna(inplace=True)
    y = np.array(label)
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=test_size, random_state=0)
    response = {
        'x_train': x_train,
        'x_test': x_test,
        'y_train': y_train,
        'y_test': y_test,
        'x_lately': x_lately
    }
    return response

# %%
df = pd.read_csv('..\data\BTC-USD.csv')
df
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\SAM-Tech\AppData\Local\Temp\ipykernel_5500\628327737.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df = pd.read_csv('..\data\BTC-USD.csv')
#             Date          Open          High           Low         Close  \
# 0     2020-04-11   6867.440430   6926.069824   6789.920898   6859.083008
# 1     2020-04-12   6858.067871   7119.947266   6811.078125   6971.091797
# 2     2020-04-13   6965.616699   6965.616699   6668.259766   6845.037598
# 3     2020-04-14   6843.281738   6958.557129   6793.821289   6842.427734
# 4     2020-04-15   6845.561523   6928.664551   6633.402832   6642.109863
# ...          ...           ...           ...           ...           ...
# 1457  2024-04-07  68897.109375  70284.429688  68851.632813  69362.554688
# 1458  2024-04-08  69362.554688  72715.359375  69064.242188  71631.359375
# 1459  2024-04-09  71632.500000  71742.507813  68212.921875  69139.015625
# 1460  2024-04-10  69140.242188  71093.429688  67503.562500  70587.882813
# 1461  2024-04-11  70635.023438  71244.460938  69590.742188  70210.023438
#
#          Adj Close       Volume
# 0      6859.083008  31222085946
# 1      6971.091797  35759567632
# 2      6845.037598  38619308647
# 3      6842.427734  34110434052
# 4      6642.109863  32288311031
# ...            ...          ...
# 1457  69362.554688  21204930369
# 1458  71631.359375  37261432669
# 1459  69139.015625  36426900409
# 1460  70587.882813  38318601774
# 1461  70210.023438  32427251712
#
# [1462 rows x 7 columns]

# %%
forecast_col = 'Close'
forecast_out = 5
test_size = 0.2

# %%
model = LinearRegression()
data = prepare_data(df, forecast_col, forecast_out, test_size)
x_train, x_test, y_train, y_test, x_lately = data['x_train'], data['x_test'], data['y_train'], data['y_test'], data['x_lately']
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
score = model.score(x_test,y_test)
forecast  = model.predict(x_lately)
response = {}
response['score'] = score
response['forecast'] = forecast
print(response)
# Out:
# {'score': 0.9711253265085474, 'forecast': array([69070.53658887, 71310.98763448, 68849.79113189, 70280.55157809,
#        69907.41437652])}
