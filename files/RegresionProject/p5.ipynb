# %%
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
mdf = pd.read_csv('..\data\MicrosoftStock.csv')
mdf.set_index(pd.DatetimeIndex(mdf['date'].values), inplace=True)
mdf
mdf.drop(['date','Name','index'],axis=1,inplace=True)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\SAM-Tech\AppData\Local\Temp\ipykernel_19748\203459464.py:1: SyntaxWarning: invalid escape sequence '\d'
#   mdf = pd.read_csv('..\data\MicrosoftStock.csv')

# %%
plt.plot(mdf.index,mdf['close'],color='green')
plt.legend()
# Out:
# C:\Users\SAM-Tech\AppData\Local\Temp\ipykernel_19748\2000285518.py:2: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
